# %%
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
class CustomMultinomialNB:
    def __init__(self, alpha=1.0):
        self.alpha = alpha  # Smoothing parameter
        self.class_probs = None
        self.word_probs = None
        self.classes = None
        self.vocab = None

    def _calculate_class_probs(self, y):
        class_probs = {}
        total_samples = len(y)

        for c in self.classes:
            class_count = np.sum(y == c)
            class_probs[c] = (class_count + self.alpha) / (total_samples + len(self.classes) * self.alpha)

        return class_probs

    def _calculate_word_probs(self, X, y):
      word_probs = {}

      for c in self.classes:
          class_mask = (y == c)
          class_word_count = np.sum(X[class_mask, :], axis=0)
          total_words_in_class = np.sum(X[class_mask, :]) + len(self.vocab) * self.alpha

          # Laplace smoothing for sparse matrices
          word_probs[c] = np.log((class_word_count + self.alpha) / total_words_in_class)

      return word_probs


    def fit(self, X, y):
        self.classes = np.unique(y)
        self.vocab = np.unique(X)  # Use unique words in all texts as vocabulary

        self.class_probs = self._calculate_class_probs(y)
        self.word_probs = self._calculate_word_probs(X, y)

    def _predict_instance(self, x):
      scores = {}

      for c in self.classes:
          class_score = np.sum(np.asarray(x).ravel() * np.asarray(self.word_probs[c]).ravel()) + np.log(self.class_probs[c])
          scores[c] = class_score

      return max(scores, key=scores.get)


    def predict(self, X):
        predictions = []

        for i in range(X.shape[0]):
            instance = X[i, :]
            predicted_class = self._predict_instance(instance)
            predictions.append(predicted_class)

        return np.array(predictions)

# %%
data = fetch_20newsgroups()
categories = data.target_names

# %%
# Divide the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2, random_state=42)

# %%
# Convert text data to a bag-of-words representation
vectorizer = CountVectorizer()
X_train_bow = vectorizer.fit_transform(X_train)
X_test_bow = vectorizer.transform(X_test)

# %%
# Create and train the custom Multinomial Naive Bayes classifier
custom_classifier = CustomMultinomialNB()
# Create and train the custom Multinomial Naive Bayes classifier
custom_classifier = CustomMultinomialNB()
try:
    custom_classifier.fit(X_train_bow, y_train)
except Exception as e:
    print("Error during training:", e)

# %%
# Predict labels for test data
predicted_labels = custom_classifier.predict(X_test_bow.toarray())

# %%
# Calculate accuracy score
accuracy = accuracy_score(y_test, predicted_labels)

print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 85.15%

# %%
# Print actual and predicted categories for all texts
for i, (actual_category, predicted_category) in enumerate(zip(y_test, predicted_labels)):
    actual_category_name = data.target_names[actual_category]
    predicted_category_name = data.target_names[predicted_category]

    print(f"Text {i+1}: Actual - {actual_category_name}, Predicted - {predicted_category_name}")
# Out:
# Text 1: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 2: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 3: Actual - misc.forsale, Predicted - misc.forsale
# Text 4: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 5: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 6: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 7: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 8: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 9: Actual - sci.space, Predicted - sci.space
# Text 10: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 11: Actual - rec.autos, Predicted - rec.autos
# Text 12: Actual - misc.forsale, Predicted - misc.forsale
# Text 13: Actual - soc.religion.christian, Predicted - alt.atheism
# Text 14: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.graphics
# Text 15: Actual - sci.crypt, Predicted - sci.crypt
# Text 16: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 17: Actual - sci.electronics, Predicted - comp.sys.mac.hardware
# Text 18: Actual - rec.sport.hockey, Predicted - rec.sport.baseball
# Text 19: Actual - sci.med, Predicted - sci.med
# Text 20: Actual - rec.autos, Predicted - rec.autos
# Text 21: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 22: Actual - sci.electronics, Predicted - sci.electronics
# Text 23: Actual - sci.med, Predicted - sci.med
# Text 24: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 25: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 26: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 27: Actual - talk.politics.mideast, Predicted - misc.forsale
# Text 28: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 29: Actual - comp.graphics, Predicted - comp.graphics
# Text 30: Actual - sci.space, Predicted - sci.space
# Text 31: Actual - sci.crypt, Predicted - sci.crypt
# Text 32: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 33: Actual - sci.electronics, Predicted - sci.electronics
# Text 34: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 35: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 36: Actual - sci.crypt, Predicted - sci.crypt
# Text 37: Actual - misc.forsale, Predicted - misc.forsale
# Text 38: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 39: Actual - alt.atheism, Predicted - alt.atheism
# Text 40: Actual - sci.med, Predicted - comp.graphics
# Text 41: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 42: Actual - rec.motorcycles, Predicted - rec.autos
# Text 43: Actual - sci.space, Predicted - sci.space
# Text 44: Actual - alt.atheism, Predicted - alt.atheism
# Text 45: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 46: Actual - sci.space, Predicted - sci.space
# Text 47: Actual - comp.graphics, Predicted - comp.graphics
# Text 48: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 49: Actual - sci.med, Predicted - sci.med
# Text 50: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 51: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 52: Actual - sci.crypt, Predicted - comp.graphics
# Text 53: Actual - comp.graphics, Predicted - comp.graphics
# Text 54: Actual - sci.space, Predicted - sci.space
# Text 55: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 56: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 57: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 58: Actual - comp.os.ms-windows.misc, Predicted - comp.windows.x
# Text 59: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 60: Actual - sci.electronics, Predicted - sci.electronics
# Text 61: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 62: Actual - sci.crypt, Predicted - sci.crypt
# Text 63: Actual - sci.space, Predicted - sci.space
# Text 64: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 65: Actual - sci.space, Predicted - sci.space
# Text 66: Actual - sci.med, Predicted - sci.med
# Text 67: Actual - misc.forsale, Predicted - misc.forsale
# Text 68: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 69: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 70: Actual - sci.space, Predicted - sci.space
# Text 71: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 72: Actual - misc.forsale, Predicted - misc.forsale
# Text 73: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 74: Actual - misc.forsale, Predicted - misc.forsale
# Text 75: Actual - misc.forsale, Predicted - comp.sys.mac.hardware
# Text 76: Actual - sci.med, Predicted - sci.med
# Text 77: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 78: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 79: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 80: Actual - misc.forsale, Predicted - misc.forsale
# Text 81: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 82: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 83: Actual - comp.graphics, Predicted - comp.graphics
# Text 84: Actual - sci.electronics, Predicted - sci.electronics
# Text 85: Actual - comp.windows.x, Predicted - misc.forsale
# Text 86: Actual - comp.sys.ibm.pc.hardware, Predicted - misc.forsale
# Text 87: Actual - sci.electronics, Predicted - sci.electronics
# Text 88: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 89: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 90: Actual - sci.med, Predicted - sci.med
# Text 91: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 92: Actual - talk.politics.mideast, Predicted - talk.religion.misc
# Text 93: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 94: Actual - sci.electronics, Predicted - sci.electronics
# Text 95: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 96: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 97: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 98: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 99: Actual - sci.electronics, Predicted - sci.electronics
# Text 100: Actual - rec.autos, Predicted - rec.autos
# Text 101: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.mac.hardware
# Text 102: Actual - sci.electronics, Predicted - sci.electronics
# Text 103: Actual - alt.atheism, Predicted - alt.atheism
# Text 104: Actual - misc.forsale, Predicted - misc.forsale
# Text 105: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 106: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 107: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 108: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 109: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 110: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 111: Actual - sci.med, Predicted - sci.med
# Text 112: Actual - rec.autos, Predicted - rec.autos
# Text 113: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 114: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.mac.hardware
# Text 115: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 116: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 117: Actual - sci.med, Predicted - sci.med
# Text 118: Actual - comp.graphics, Predicted - comp.graphics
# Text 119: Actual - comp.graphics, Predicted - comp.graphics
# Text 120: Actual - alt.atheism, Predicted - alt.atheism
# Text 121: Actual - sci.electronics, Predicted - comp.sys.mac.hardware
# Text 122: Actual - alt.atheism, Predicted - alt.atheism
# Text 123: Actual - comp.windows.x, Predicted - comp.graphics
# Text 124: Actual - sci.space, Predicted - sci.space
# Text 125: Actual - alt.atheism, Predicted - alt.atheism
# Text 126: Actual - sci.crypt, Predicted - sci.crypt
# Text 127: Actual - sci.med, Predicted - sci.med
# Text 128: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 129: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 130: Actual - misc.forsale, Predicted - misc.forsale
# Text 131: Actual - sci.space, Predicted - sci.space
# Text 132: Actual - sci.crypt, Predicted - sci.crypt
# Text 133: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 134: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 135: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 136: Actual - sci.space, Predicted - sci.space
# Text 137: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 138: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.mac.hardware
# Text 139: Actual - sci.med, Predicted - sci.med
# Text 140: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 141: Actual - sci.space, Predicted - sci.space
# Text 142: Actual - sci.crypt, Predicted - sci.crypt
# Text 143: Actual - comp.graphics, Predicted - comp.graphics
# Text 144: Actual - rec.autos, Predicted - rec.autos
# Text 145: Actual - sci.space, Predicted - sci.space
# Text 146: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 147: Actual - sci.crypt, Predicted - sci.crypt
# Text 148: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 149: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.mac.hardware
# Text 150: Actual - comp.graphics, Predicted - comp.graphics
# Text 151: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 152: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 153: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 154: Actual - sci.space, Predicted - sci.space
# Text 155: Actual - talk.politics.mideast, Predicted - misc.forsale
# Text 156: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 157: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 158: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 159: Actual - comp.graphics, Predicted - comp.graphics
# Text 160: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 161: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 162: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 163: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 164: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 165: Actual - misc.forsale, Predicted - misc.forsale
# Text 166: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 167: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 168: Actual - alt.atheism, Predicted - alt.atheism
# Text 169: Actual - rec.autos, Predicted - rec.autos
# Text 170: Actual - alt.atheism, Predicted - alt.atheism
# Text 171: Actual - rec.autos, Predicted - rec.autos
# Text 172: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 173: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 174: Actual - sci.electronics, Predicted - comp.sys.mac.hardware
# Text 175: Actual - misc.forsale, Predicted - misc.forsale
# Text 176: Actual - sci.electronics, Predicted - comp.sys.ibm.pc.hardware
# Text 177: Actual - sci.med, Predicted - sci.med
# Text 178: Actual - sci.electronics, Predicted - comp.sys.mac.hardware
# Text 179: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 180: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 181: Actual - talk.politics.mideast, Predicted - misc.forsale
# Text 182: Actual - misc.forsale, Predicted - comp.sys.ibm.pc.hardware
# Text 183: Actual - rec.autos, Predicted - rec.autos
# Text 184: Actual - alt.atheism, Predicted - alt.atheism
# Text 185: Actual - misc.forsale, Predicted - misc.forsale
# Text 186: Actual - sci.electronics, Predicted - sci.electronics
# Text 187: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 188: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 189: Actual - sci.med, Predicted - sci.med
# Text 190: Actual - sci.med, Predicted - sci.med
# Text 191: Actual - rec.autos, Predicted - rec.autos
# Text 192: Actual - sci.med, Predicted - sci.med
# Text 193: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 194: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 195: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 196: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 197: Actual - sci.electronics, Predicted - comp.sys.mac.hardware
# Text 198: Actual - sci.med, Predicted - sci.med
# Text 199: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 200: Actual - rec.sport.hockey, Predicted - rec.autos
# Text 201: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 202: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 203: Actual - sci.crypt, Predicted - sci.crypt
# Text 204: Actual - alt.atheism, Predicted - alt.atheism
# Text 205: Actual - rec.autos, Predicted - rec.autos
# Text 206: Actual - sci.crypt, Predicted - talk.religion.misc
# Text 207: Actual - misc.forsale, Predicted - misc.forsale
# Text 208: Actual - sci.space, Predicted - sci.space
# Text 209: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 210: Actual - sci.space, Predicted - sci.space
# Text 211: Actual - rec.autos, Predicted - rec.autos
# Text 212: Actual - misc.forsale, Predicted - rec.autos
# Text 213: Actual - comp.os.ms-windows.misc, Predicted - comp.windows.x
# Text 214: Actual - sci.med, Predicted - sci.med
# Text 215: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 216: Actual - sci.space, Predicted - sci.space
# Text 217: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 218: Actual - rec.autos, Predicted - rec.motorcycles
# Text 219: Actual - rec.autos, Predicted - rec.autos
# Text 220: Actual - sci.med, Predicted - sci.med
# Text 221: Actual - rec.autos, Predicted - rec.autos
# Text 222: Actual - sci.electronics, Predicted - sci.electronics
# Text 223: Actual - comp.graphics, Predicted - comp.sys.mac.hardware
# Text 224: Actual - sci.electronics, Predicted - sci.electronics
# Text 225: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 226: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 227: Actual - sci.crypt, Predicted - sci.crypt
# Text 228: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 229: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 230: Actual - comp.graphics, Predicted - comp.graphics
# Text 231: Actual - sci.space, Predicted - sci.space
# Text 232: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 233: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 234: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.mac.hardware
# Text 235: Actual - rec.autos, Predicted - rec.autos
# Text 236: Actual - rec.autos, Predicted - rec.autos
# Text 237: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 238: Actual - rec.motorcycles, Predicted - misc.forsale
# Text 239: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.graphics
# Text 240: Actual - sci.electronics, Predicted - misc.forsale
# Text 241: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 242: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 243: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 244: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 245: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 246: Actual - talk.politics.misc, Predicted - talk.politics.mideast
# Text 247: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 248: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 249: Actual - alt.atheism, Predicted - alt.atheism
# Text 250: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 251: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 252: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 253: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 254: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 255: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 256: Actual - rec.motorcycles, Predicted - rec.autos
# Text 257: Actual - sci.electronics, Predicted - sci.electronics
# Text 258: Actual - rec.autos, Predicted - rec.autos
# Text 259: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 260: Actual - sci.crypt, Predicted - sci.crypt
# Text 261: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 262: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 263: Actual - comp.windows.x, Predicted - comp.sys.ibm.pc.hardware
# Text 264: Actual - rec.autos, Predicted - rec.autos
# Text 265: Actual - rec.autos, Predicted - rec.autos
# Text 266: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 267: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 268: Actual - sci.med, Predicted - sci.med
# Text 269: Actual - comp.graphics, Predicted - comp.graphics
# Text 270: Actual - sci.space, Predicted - sci.space
# Text 271: Actual - talk.religion.misc, Predicted - alt.atheism
# Text 272: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 273: Actual - rec.autos, Predicted - rec.autos
# Text 274: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 275: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 276: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 277: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 278: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 279: Actual - sci.electronics, Predicted - comp.sys.mac.hardware
# Text 280: Actual - sci.space, Predicted - sci.space
# Text 281: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 282: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 283: Actual - talk.religion.misc, Predicted - soc.religion.christian
# Text 284: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 285: Actual - sci.space, Predicted - sci.space
# Text 286: Actual - alt.atheism, Predicted - alt.atheism
# Text 287: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 288: Actual - rec.autos, Predicted - rec.autos
# Text 289: Actual - misc.forsale, Predicted - misc.forsale
# Text 290: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 291: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 292: Actual - misc.forsale, Predicted - misc.forsale
# Text 293: Actual - sci.med, Predicted - sci.med
# Text 294: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 295: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 296: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 297: Actual - sci.med, Predicted - sci.med
# Text 298: Actual - rec.autos, Predicted - comp.sys.mac.hardware
# Text 299: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 300: Actual - sci.crypt, Predicted - sci.crypt
# Text 301: Actual - talk.religion.misc, Predicted - alt.atheism
# Text 302: Actual - sci.med, Predicted - sci.med
# Text 303: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 304: Actual - comp.graphics, Predicted - comp.sys.mac.hardware
# Text 305: Actual - rec.autos, Predicted - rec.autos
# Text 306: Actual - comp.sys.ibm.pc.hardware, Predicted - misc.forsale
# Text 307: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 308: Actual - sci.med, Predicted - sci.med
# Text 309: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 310: Actual - misc.forsale, Predicted - misc.forsale
# Text 311: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 312: Actual - comp.windows.x, Predicted - comp.sys.ibm.pc.hardware
# Text 313: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 314: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 315: Actual - comp.sys.mac.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 316: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 317: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 318: Actual - rec.autos, Predicted - rec.autos
# Text 319: Actual - sci.space, Predicted - sci.space
# Text 320: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 321: Actual - sci.electronics, Predicted - sci.electronics
# Text 322: Actual - comp.graphics, Predicted - comp.graphics
# Text 323: Actual - rec.motorcycles, Predicted - misc.forsale
# Text 324: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 325: Actual - sci.electronics, Predicted - sci.electronics
# Text 326: Actual - talk.politics.mideast, Predicted - rec.autos
# Text 327: Actual - sci.med, Predicted - sci.electronics
# Text 328: Actual - sci.space, Predicted - sci.space
# Text 329: Actual - misc.forsale, Predicted - misc.forsale
# Text 330: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 331: Actual - comp.os.ms-windows.misc, Predicted - misc.forsale
# Text 332: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 333: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 334: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.mac.hardware
# Text 335: Actual - alt.atheism, Predicted - alt.atheism
# Text 336: Actual - alt.atheism, Predicted - alt.atheism
# Text 337: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 338: Actual - comp.os.ms-windows.misc, Predicted - comp.windows.x
# Text 339: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 340: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 341: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 342: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 343: Actual - sci.electronics, Predicted - sci.electronics
# Text 344: Actual - sci.crypt, Predicted - comp.graphics
# Text 345: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 346: Actual - sci.med, Predicted - sci.med
# Text 347: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 348: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 349: Actual - alt.atheism, Predicted - alt.atheism
# Text 350: Actual - comp.os.ms-windows.misc, Predicted - comp.os.ms-windows.misc
# Text 351: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.mac.hardware
# Text 352: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 353: Actual - comp.windows.x, Predicted - comp.sys.ibm.pc.hardware
# Text 354: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.mac.hardware
# Text 355: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 356: Actual - sci.crypt, Predicted - sci.crypt
# Text 357: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 358: Actual - misc.forsale, Predicted - misc.forsale
# Text 359: Actual - sci.crypt, Predicted - sci.crypt
# Text 360: Actual - sci.space, Predicted - sci.space
# Text 361: Actual - sci.electronics, Predicted - sci.electronics
# Text 362: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 363: Actual - sci.space, Predicted - sci.space
# Text 364: Actual - talk.politics.misc, Predicted - talk.religion.misc
# Text 365: Actual - misc.forsale, Predicted - misc.forsale
# Text 366: Actual - sci.med, Predicted - sci.med
# Text 367: Actual - sci.crypt, Predicted - sci.crypt
# Text 368: Actual - sci.crypt, Predicted - sci.crypt
# Text 369: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 370: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 371: Actual - sci.space, Predicted - sci.space
# Text 372: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 373: Actual - rec.autos, Predicted - sci.electronics
# Text 374: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 375: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 376: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 377: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 378: Actual - rec.autos, Predicted - rec.autos
# Text 379: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 380: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 381: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 382: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 383: Actual - alt.atheism, Predicted - alt.atheism
# Text 384: Actual - sci.crypt, Predicted - sci.crypt
# Text 385: Actual - alt.atheism, Predicted - alt.atheism
# Text 386: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 387: Actual - sci.space, Predicted - sci.space
# Text 388: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 389: Actual - comp.graphics, Predicted - comp.graphics
# Text 390: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 391: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 392: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 393: Actual - sci.med, Predicted - sci.med
# Text 394: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 395: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 396: Actual - sci.electronics, Predicted - sci.electronics
# Text 397: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 398: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 399: Actual - rec.autos, Predicted - rec.autos
# Text 400: Actual - talk.politics.misc, Predicted - misc.forsale
# Text 401: Actual - misc.forsale, Predicted - misc.forsale
# Text 402: Actual - sci.electronics, Predicted - sci.electronics
# Text 403: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 404: Actual - sci.med, Predicted - sci.med
# Text 405: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 406: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 407: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 408: Actual - sci.electronics, Predicted - sci.electronics
# Text 409: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 410: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 411: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 412: Actual - comp.graphics, Predicted - comp.graphics
# Text 413: Actual - sci.crypt, Predicted - sci.crypt
# Text 414: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 415: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 416: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 417: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 418: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 419: Actual - misc.forsale, Predicted - misc.forsale
# Text 420: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 421: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 422: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 423: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 424: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 425: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 426: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 427: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 428: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 429: Actual - sci.med, Predicted - sci.med
# Text 430: Actual - sci.electronics, Predicted - comp.graphics
# Text 431: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 432: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 433: Actual - alt.atheism, Predicted - alt.atheism
# Text 434: Actual - sci.crypt, Predicted - sci.crypt
# Text 435: Actual - sci.electronics, Predicted - sci.electronics
# Text 436: Actual - misc.forsale, Predicted - misc.forsale
# Text 437: Actual - alt.atheism, Predicted - alt.atheism
# Text 438: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 439: Actual - sci.space, Predicted - sci.space
# Text 440: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 441: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 442: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 443: Actual - sci.electronics, Predicted - sci.electronics
# Text 444: Actual - rec.autos, Predicted - misc.forsale
# Text 445: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 446: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 447: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 448: Actual - sci.space, Predicted - sci.space
# Text 449: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 450: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 451: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 452: Actual - talk.politics.misc, Predicted - talk.religion.misc
# Text 453: Actual - soc.religion.christian, Predicted - talk.religion.misc
# Text 454: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 455: Actual - misc.forsale, Predicted - misc.forsale
# Text 456: Actual - comp.windows.x, Predicted - comp.graphics
# Text 457: Actual - sci.electronics, Predicted - sci.electronics
# Text 458: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 459: Actual - comp.graphics, Predicted - comp.graphics
# Text 460: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 461: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 462: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 463: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 464: Actual - rec.sport.hockey, Predicted - misc.forsale
# Text 465: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 466: Actual - misc.forsale, Predicted - misc.forsale
# Text 467: Actual - sci.space, Predicted - sci.space
# Text 468: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 469: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 470: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 471: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 472: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 473: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 474: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 475: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 476: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 477: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 478: Actual - rec.autos, Predicted - rec.autos
# Text 479: Actual - sci.electronics, Predicted - sci.electronics
# Text 480: Actual - alt.atheism, Predicted - alt.atheism
# Text 481: Actual - comp.graphics, Predicted - comp.graphics
# Text 482: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 483: Actual - talk.politics.mideast, Predicted - misc.forsale
# Text 484: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 485: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 486: Actual - sci.crypt, Predicted - sci.crypt
# Text 487: Actual - alt.atheism, Predicted - alt.atheism
# Text 488: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 489: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 490: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 491: Actual - comp.graphics, Predicted - comp.graphics
# Text 492: Actual - rec.autos, Predicted - rec.autos
# Text 493: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 494: Actual - talk.religion.misc, Predicted - talk.politics.misc
# Text 495: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 496: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 497: Actual - sci.electronics, Predicted - sci.electronics
# Text 498: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 499: Actual - sci.space, Predicted - sci.space
# Text 500: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 501: Actual - rec.autos, Predicted - rec.autos
# Text 502: Actual - sci.space, Predicted - sci.space
# Text 503: Actual - misc.forsale, Predicted - misc.forsale
# Text 504: Actual - comp.graphics, Predicted - misc.forsale
# Text 505: Actual - comp.graphics, Predicted - comp.graphics
# Text 506: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 507: Actual - sci.space, Predicted - sci.space
# Text 508: Actual - sci.space, Predicted - sci.space
# Text 509: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 510: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 511: Actual - alt.atheism, Predicted - sci.space
# Text 512: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 513: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 514: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 515: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 516: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 517: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 518: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 519: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 520: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 521: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 522: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 523: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 524: Actual - rec.autos, Predicted - rec.autos
# Text 525: Actual - sci.space, Predicted - sci.space
# Text 526: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 527: Actual - alt.atheism, Predicted - alt.atheism
# Text 528: Actual - misc.forsale, Predicted - misc.forsale
# Text 529: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 530: Actual - sci.electronics, Predicted - comp.sys.ibm.pc.hardware
# Text 531: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 532: Actual - sci.electronics, Predicted - misc.forsale
# Text 533: Actual - alt.atheism, Predicted - alt.atheism
# Text 534: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 535: Actual - misc.forsale, Predicted - misc.forsale
# Text 536: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 537: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 538: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 539: Actual - sci.electronics, Predicted - sci.electronics
# Text 540: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 541: Actual - rec.autos, Predicted - rec.autos
# Text 542: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 543: Actual - rec.autos, Predicted - rec.autos
# Text 544: Actual - misc.forsale, Predicted - misc.forsale
# Text 545: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 546: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 547: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 548: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 549: Actual - sci.electronics, Predicted - sci.electronics
# Text 550: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 551: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 552: Actual - alt.atheism, Predicted - alt.atheism
# Text 553: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 554: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 555: Actual - sci.med, Predicted - sci.med
# Text 556: Actual - sci.electronics, Predicted - sci.electronics
# Text 557: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 558: Actual - talk.religion.misc, Predicted - misc.forsale
# Text 559: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 560: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 561: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 562: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 563: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 564: Actual - misc.forsale, Predicted - misc.forsale
# Text 565: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 566: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 567: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 568: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 569: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 570: Actual - comp.graphics, Predicted - comp.graphics
# Text 571: Actual - alt.atheism, Predicted - alt.atheism
# Text 572: Actual - sci.space, Predicted - sci.space
# Text 573: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 574: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 575: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 576: Actual - sci.med, Predicted - sci.med
# Text 577: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 578: Actual - misc.forsale, Predicted - misc.forsale
# Text 579: Actual - alt.atheism, Predicted - alt.atheism
# Text 580: Actual - rec.autos, Predicted - rec.autos
# Text 581: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 582: Actual - misc.forsale, Predicted - misc.forsale
# Text 583: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 584: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 585: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 586: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 587: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 588: Actual - talk.religion.misc, Predicted - alt.atheism
# Text 589: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 590: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 591: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 592: Actual - rec.autos, Predicted - rec.autos
# Text 593: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 594: Actual - sci.space, Predicted - sci.space
# Text 595: Actual - sci.space, Predicted - comp.graphics
# Text 596: Actual - sci.electronics, Predicted - sci.electronics
# Text 597: Actual - alt.atheism, Predicted - alt.atheism
# Text 598: Actual - talk.politics.mideast, Predicted - talk.politics.misc
# Text 599: Actual - sci.med, Predicted - sci.med
# Text 600: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 601: Actual - sci.electronics, Predicted - sci.electronics
# Text 602: Actual - sci.space, Predicted - sci.space
# Text 603: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 604: Actual - sci.space, Predicted - sci.space
# Text 605: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 606: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 607: Actual - rec.sport.hockey, Predicted - comp.sys.mac.hardware
# Text 608: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 609: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 610: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 611: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 612: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 613: Actual - rec.sport.hockey, Predicted - rec.sport.baseball
# Text 614: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 615: Actual - sci.space, Predicted - sci.space
# Text 616: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 617: Actual - sci.med, Predicted - sci.med
# Text 618: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 619: Actual - comp.graphics, Predicted - comp.graphics
# Text 620: Actual - alt.atheism, Predicted - alt.atheism
# Text 621: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 622: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 623: Actual - talk.religion.misc, Predicted - talk.politics.misc
# Text 624: Actual - sci.electronics, Predicted - sci.electronics
# Text 625: Actual - sci.crypt, Predicted - sci.crypt
# Text 626: Actual - rec.autos, Predicted - rec.autos
# Text 627: Actual - sci.space, Predicted - sci.space
# Text 628: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 629: Actual - sci.space, Predicted - sci.space
# Text 630: Actual - comp.graphics, Predicted - comp.graphics
# Text 631: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 632: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 633: Actual - sci.electronics, Predicted - sci.electronics
# Text 634: Actual - talk.religion.misc, Predicted - soc.religion.christian
# Text 635: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 636: Actual - misc.forsale, Predicted - misc.forsale
# Text 637: Actual - sci.crypt, Predicted - sci.crypt
# Text 638: Actual - sci.electronics, Predicted - sci.electronics
# Text 639: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 640: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 641: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 642: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 643: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 644: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 645: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 646: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 647: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 648: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 649: Actual - comp.graphics, Predicted - comp.graphics
# Text 650: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 651: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 652: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 653: Actual - alt.atheism, Predicted - alt.atheism
# Text 654: Actual - comp.graphics, Predicted - comp.graphics
# Text 655: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 656: Actual - rec.autos, Predicted - rec.autos
# Text 657: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 658: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 659: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 660: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 661: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 662: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 663: Actual - sci.crypt, Predicted - sci.crypt
# Text 664: Actual - sci.med, Predicted - sci.med
# Text 665: Actual - sci.space, Predicted - sci.space
# Text 666: Actual - sci.electronics, Predicted - sci.electronics
# Text 667: Actual - sci.crypt, Predicted - sci.crypt
# Text 668: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 669: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 670: Actual - rec.autos, Predicted - rec.autos
# Text 671: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 672: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 673: Actual - alt.atheism, Predicted - alt.atheism
# Text 674: Actual - sci.crypt, Predicted - sci.crypt
# Text 675: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 676: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 677: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 678: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 679: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 680: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 681: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 682: Actual - sci.electronics, Predicted - sci.electronics
# Text 683: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 684: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 685: Actual - rec.autos, Predicted - rec.autos
# Text 686: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 687: Actual - misc.forsale, Predicted - misc.forsale
# Text 688: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 689: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 690: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 691: Actual - sci.space, Predicted - sci.space
# Text 692: Actual - sci.med, Predicted - sci.med
# Text 693: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 694: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 695: Actual - sci.crypt, Predicted - sci.crypt
# Text 696: Actual - misc.forsale, Predicted - misc.forsale
# Text 697: Actual - rec.autos, Predicted - rec.autos
# Text 698: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 699: Actual - misc.forsale, Predicted - misc.forsale
# Text 700: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 701: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 702: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 703: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 704: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 705: Actual - sci.electronics, Predicted - sci.electronics
# Text 706: Actual - sci.med, Predicted - sci.med
# Text 707: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 708: Actual - alt.atheism, Predicted - alt.atheism
# Text 709: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 710: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.mac.hardware
# Text 711: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 712: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 713: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 714: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 715: Actual - misc.forsale, Predicted - misc.forsale
# Text 716: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 717: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 718: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 719: Actual - rec.autos, Predicted - rec.autos
# Text 720: Actual - rec.autos, Predicted - rec.autos
# Text 721: Actual - sci.med, Predicted - sci.med
# Text 722: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 723: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 724: Actual - sci.electronics, Predicted - sci.electronics
# Text 725: Actual - comp.graphics, Predicted - comp.graphics
# Text 726: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 727: Actual - misc.forsale, Predicted - misc.forsale
# Text 728: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 729: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 730: Actual - rec.autos, Predicted - rec.autos
# Text 731: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 732: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 733: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 734: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 735: Actual - sci.crypt, Predicted - sci.crypt
# Text 736: Actual - alt.atheism, Predicted - alt.atheism
# Text 737: Actual - misc.forsale, Predicted - misc.forsale
# Text 738: Actual - sci.space, Predicted - sci.space
# Text 739: Actual - sci.electronics, Predicted - sci.electronics
# ...
# Text 2023: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 2024: Actual - talk.religion.misc, Predicted - alt.atheism
# Text 2025: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 2026: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2027: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2028: Actual - comp.graphics, Predicted - comp.graphics
# Text 2029: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2030: Actual - alt.atheism, Predicted - alt.atheism
# Text 2031: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2032: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2033: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 2034: Actual - sci.med, Predicted - sci.med
# Text 2035: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2036: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 2037: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2038: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 2039: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 2040: Actual - rec.autos, Predicted - rec.autos
# Text 2041: Actual - sci.space, Predicted - sci.space
# Text 2042: Actual - comp.graphics, Predicted - comp.windows.x
# Text 2043: Actual - sci.med, Predicted - sci.med
# Text 2044: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 2045: Actual - misc.forsale, Predicted - misc.forsale
# Text 2046: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2047: Actual - alt.atheism, Predicted - alt.atheism
# Text 2048: Actual - sci.space, Predicted - sci.space
# Text 2049: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2050: Actual - sci.electronics, Predicted - sci.electronics
# Text 2051: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 2052: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2053: Actual - sci.crypt, Predicted - sci.crypt
# Text 2054: Actual - sci.electronics, Predicted - sci.electronics
# Text 2055: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 2056: Actual - comp.windows.x, Predicted - talk.religion.misc
# Text 2057: Actual - sci.electronics, Predicted - sci.electronics
# Text 2058: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2059: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2060: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 2061: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.mac.hardware
# Text 2062: Actual - sci.crypt, Predicted - sci.crypt
# Text 2063: Actual - misc.forsale, Predicted - misc.forsale
# Text 2064: Actual - sci.electronics, Predicted - sci.electronics
# Text 2065: Actual - misc.forsale, Predicted - misc.forsale
# Text 2066: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 2067: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2068: Actual - sci.electronics, Predicted - sci.electronics
# Text 2069: Actual - rec.autos, Predicted - rec.autos
# Text 2070: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 2071: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2072: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2073: Actual - sci.electronics, Predicted - comp.sys.ibm.pc.hardware
# Text 2074: Actual - soc.religion.christian, Predicted - comp.sys.mac.hardware
# Text 2075: Actual - alt.atheism, Predicted - alt.atheism
# Text 2076: Actual - sci.crypt, Predicted - sci.crypt
# Text 2077: Actual - sci.crypt, Predicted - talk.politics.misc
# Text 2078: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2079: Actual - rec.motorcycles, Predicted - misc.forsale
# Text 2080: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 2081: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2082: Actual - comp.graphics, Predicted - comp.graphics
# Text 2083: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.mac.hardware
# Text 2084: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2085: Actual - sci.crypt, Predicted - sci.crypt
# Text 2086: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 2087: Actual - comp.graphics, Predicted - comp.graphics
# Text 2088: Actual - sci.med, Predicted - sci.med
# Text 2089: Actual - comp.graphics, Predicted - comp.sys.ibm.pc.hardware
# Text 2090: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2091: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2092: Actual - misc.forsale, Predicted - misc.forsale
# Text 2093: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2094: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 2095: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 2096: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 2097: Actual - comp.graphics, Predicted - comp.graphics
# Text 2098: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 2099: Actual - comp.os.ms-windows.misc, Predicted - comp.os.ms-windows.misc
# Text 2100: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 2101: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2102: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2103: Actual - sci.med, Predicted - sci.med
# Text 2104: Actual - sci.space, Predicted - sci.space
# Text 2105: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 2106: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 2107: Actual - rec.autos, Predicted - rec.autos
# Text 2108: Actual - comp.windows.x, Predicted - comp.sys.ibm.pc.hardware
# Text 2109: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2110: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2111: Actual - sci.electronics, Predicted - sci.electronics
# Text 2112: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2113: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 2114: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2115: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 2116: Actual - comp.graphics, Predicted - comp.graphics
# Text 2117: Actual - rec.autos, Predicted - rec.autos
# Text 2118: Actual - sci.space, Predicted - sci.space
# Text 2119: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2120: Actual - rec.autos, Predicted - rec.autos
# Text 2121: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 2122: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2123: Actual - alt.atheism, Predicted - alt.atheism
# Text 2124: Actual - rec.autos, Predicted - rec.autos
# Text 2125: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 2126: Actual - sci.electronics, Predicted - sci.electronics
# Text 2127: Actual - comp.graphics, Predicted - comp.graphics
# Text 2128: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 2129: Actual - rec.autos, Predicted - rec.autos
# Text 2130: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 2131: Actual - rec.autos, Predicted - rec.autos
# Text 2132: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 2133: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 2134: Actual - talk.politics.guns, Predicted - rec.autos
# Text 2135: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 2136: Actual - alt.atheism, Predicted - alt.atheism
# Text 2137: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 2138: Actual - alt.atheism, Predicted - alt.atheism
# Text 2139: Actual - sci.crypt, Predicted - sci.crypt
# Text 2140: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 2141: Actual - comp.graphics, Predicted - comp.graphics
# Text 2142: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2143: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 2144: Actual - alt.atheism, Predicted - alt.atheism
# Text 2145: Actual - misc.forsale, Predicted - misc.forsale
# Text 2146: Actual - comp.graphics, Predicted - comp.graphics
# Text 2147: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 2148: Actual - misc.forsale, Predicted - misc.forsale
# Text 2149: Actual - misc.forsale, Predicted - comp.sys.mac.hardware
# Text 2150: Actual - comp.graphics, Predicted - comp.graphics
# Text 2151: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 2152: Actual - comp.graphics, Predicted - comp.graphics
# Text 2153: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 2154: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 2155: Actual - sci.electronics, Predicted - sci.electronics
# Text 2156: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2157: Actual - comp.graphics, Predicted - comp.graphics
# Text 2158: Actual - alt.atheism, Predicted - alt.atheism
# Text 2159: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 2160: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2161: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2162: Actual - sci.space, Predicted - sci.space
# Text 2163: Actual - soc.religion.christian, Predicted - misc.forsale
# Text 2164: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2165: Actual - comp.graphics, Predicted - comp.graphics
# Text 2166: Actual - comp.sys.mac.hardware, Predicted - comp.sys.mac.hardware
# Text 2167: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2168: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 2169: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 2170: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2171: Actual - sci.med, Predicted - sci.med
# Text 2172: Actual - comp.graphics, Predicted - comp.graphics
# Text 2173: Actual - comp.graphics, Predicted - comp.graphics
# Text 2174: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 2175: Actual - sci.space, Predicted - sci.space
# Text 2176: Actual - sci.electronics, Predicted - sci.electronics
# Text 2177: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 2178: Actual - sci.crypt, Predicted - talk.politics.misc
# Text 2179: Actual - comp.os.ms-windows.misc, Predicted - misc.forsale
# Text 2180: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2181: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2182: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 2183: Actual - misc.forsale, Predicted - misc.forsale
# Text 2184: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2185: Actual - talk.politics.mideast, Predicted - talk.politics.misc
# Text 2186: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 2187: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2188: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2189: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2190: Actual - alt.atheism, Predicted - alt.atheism
# Text 2191: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2192: Actual - misc.forsale, Predicted - misc.forsale
# Text 2193: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2194: Actual - rec.autos, Predicted - rec.autos
# Text 2195: Actual - misc.forsale, Predicted - misc.forsale
# Text 2196: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2197: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2198: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 2199: Actual - sci.electronics, Predicted - sci.electronics
# Text 2200: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2201: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 2202: Actual - sci.electronics, Predicted - sci.electronics
# Text 2203: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2204: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 2205: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 2206: Actual - sci.med, Predicted - rec.motorcycles
# Text 2207: Actual - rec.autos, Predicted - rec.autos
# Text 2208: Actual - sci.electronics, Predicted - sci.electronics
# Text 2209: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 2210: Actual - sci.space, Predicted - sci.space
# Text 2211: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2212: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2213: Actual - sci.electronics, Predicted - comp.sys.mac.hardware
# Text 2214: Actual - comp.os.ms-windows.misc, Predicted - rec.autos
# Text 2215: Actual - alt.atheism, Predicted - alt.atheism
# Text 2216: Actual - rec.autos, Predicted - rec.autos
# Text 2217: Actual - sci.med, Predicted - sci.med
# Text 2218: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 2219: Actual - sci.med, Predicted - sci.med
# Text 2220: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2221: Actual - talk.politics.misc, Predicted - talk.politics.misc
# Text 2222: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2223: Actual - rec.autos, Predicted - rec.autos
# Text 2224: Actual - comp.windows.x, Predicted - comp.sys.mac.hardware
# Text 2225: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2226: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2227: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 2228: Actual - sci.crypt, Predicted - sci.crypt
# Text 2229: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2230: Actual - sci.space, Predicted - sci.space
# Text 2231: Actual - sci.med, Predicted - sci.med
# Text 2232: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2233: Actual - comp.graphics, Predicted - comp.graphics
# Text 2234: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 2235: Actual - misc.forsale, Predicted - misc.forsale
# Text 2236: Actual - sci.med, Predicted - sci.med
# Text 2237: Actual - misc.forsale, Predicted - comp.sys.mac.hardware
# Text 2238: Actual - rec.sport.hockey, Predicted - rec.sport.hockey
# Text 2239: Actual - comp.windows.x, Predicted - comp.windows.x
# Text 2240: Actual - rec.sport.baseball, Predicted - misc.forsale
# Text 2241: Actual - comp.sys.ibm.pc.hardware, Predicted - comp.sys.ibm.pc.hardware
# Text 2242: Actual - sci.space, Predicted - sci.space
# Text 2243: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 2244: Actual - sci.crypt, Predicted - sci.crypt
# Text 2245: Actual - rec.sport.baseball, Predicted - alt.atheism
# Text 2246: Actual - comp.os.ms-windows.misc, Predicted - comp.sys.ibm.pc.hardware
# Text 2247: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2248: Actual - comp.sys.ibm.pc.hardware, Predicted - sci.electronics
# Text 2249: Actual - rec.motorcycles, Predicted - rec.motorcycles
# Text 2250: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2251: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 2252: Actual - talk.religion.misc, Predicted - talk.religion.misc
# Text 2253: Actual - sci.electronics, Predicted - sci.electronics
# Text 2254: Actual - rec.sport.baseball, Predicted - rec.sport.baseball
# Text 2255: Actual - sci.crypt, Predicted - sci.crypt
# Text 2256: Actual - sci.space, Predicted - sci.space
# Text 2257: Actual - comp.windows.x, Predicted - rec.motorcycles
# Text 2258: Actual - talk.politics.mideast, Predicted - talk.politics.mideast
# Text 2259: Actual - comp.os.ms-windows.misc, Predicted - comp.graphics
# Text 2260: Actual - soc.religion.christian, Predicted - soc.religion.christian
# Text 2261: Actual - sci.space, Predicted - sci.space
# Text 2262: Actual - talk.politics.guns, Predicted - talk.politics.guns
# Text 2263: Actual - sci.crypt, Predicted - sci.crypt
